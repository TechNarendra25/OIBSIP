# %% [markdown]
# # 🌸 Iris Flower Classification
#
# ## 📌 Project Overview
#
# The **Iris Flower Classification** project is a supervised machine learning classification problem. The objective is to build a predictive model that can accurately identify the species of an Iris flower based on its physical measurements.
#
# The dataset used in this project is one of the most popular datasets in machine learning, originally introduced by **Ronald A. Fisher**. It contains measurements of iris flowers from three different species.
#
# ---
#
# ## 🎯 Objective
#
# Develop and compare multiple Machine Learning classification models to classify Iris flowers into their correct species using flower measurements.
#
# ---
#
# ## 🌼 Iris Species
#
# - Iris Setosa
# - Iris Versicolor
# - Iris Virginica
#
# ---
#
# ## 📊 Input Features
#
# The model uses four numerical features:
#
# - Sepal Length (cm)
# - Sepal Width (cm)
# - Petal Length (cm)
# - Petal Width (cm)
#
# ---
#
# ## 🎯 Target Variable
#
# **Species**
#
# - Setosa
# - Versicolor
# - Virginica
#
# ---
#
# ## 🛠️ Technologies Used
#
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - Jupyter Notebook
#
# ---
#
# ## 🤖 Machine Learning Models
#
# - Logistic Regression
# - K-Nearest Neighbors (KNN)
# - Decision Tree
# - Random Forest
#
# ---
#
# ## 📈 Evaluation Metrics
#
# - Accuracy Score
# - Confusion Matrix
# - Classification Report
# - Precision
# - Recall
# - F1 Score
#
# ---
#
# ## 📚 Workflow
#
# 1. Import Libraries
# 2. Load Dataset
# 3. Dataset Understanding
# 4. Exploratory Data Analysis
# 5. Data Preprocessing
# 6. Train-Test Split
# 7. Model Training
# 8. Model Evaluation
# 9. Model Comparison
# 10. Best Model Selection
# 11. Sample Prediction
# 12. Conclusion

# %%
# ==========================================================
# Import Required Libraries
# ==========================================================

# Ignore unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning Dataset
from sklearn.datasets import load_iris

# Data Splitting
from sklearn.model_selection import train_test_split

# Machine Learning Models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Model Evaluation
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# Set Plot Style
plt.style.use("ggplot")

# Display all columns
pd.set_option("display.max_columns", None)

print("✅ All libraries imported successfully.")
# Out:
# ✅ All libraries imported successfully.

# %% [markdown]
# # 📥 Load the Iris Dataset
#
# ## Overview
#
# The Iris dataset is one of the most well-known datasets in Machine Learning. It was introduced by **Ronald A. Fisher** in 1936 and is commonly used to demonstrate classification algorithms.
#
# This dataset is available directly in the **Scikit-learn** library, so no external download is required.
#
# ### Dataset Information
#
# - Total Samples: **150**
# - Features: **4**
# - Classes: **3**
# - Target Variable: **Species**
#
# ### Features
#
# - Sepal Length (cm)
# - Sepal Width (cm)
# - Petal Length (cm)
# - Petal Width (cm)
#
# ### Target Classes
#
# - Setosa
# - Versicolor
# - Virginica

# %%
# ==========================================================
# Load the Iris Dataset
# ==========================================================

# Load dataset
iris = load_iris()

# Create DataFrame
df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

# Add target column
df["species"] = iris.target

# Convert numeric labels to species names
df["species"] = df["species"].map({
    0: "Setosa",
    1: "Versicolor",
    2: "Virginica"
})

print("✅ Dataset loaded successfully.")
# Out:
# ✅ Dataset loaded successfully.

# %%
# Display first five records
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica

# %%
df.sample(5, random_state=42)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 73                 6.1               2.8                4.7               1.2
# 18                 5.7               3.8                1.7               0.3
# 118                7.7               2.6                6.9               2.3
# 78                 6.0               2.9                4.5               1.5
# 76                 6.8               2.8                4.8               1.4
#
#         species
# 73   Versicolor
# 18       Setosa
# 118   Virginica
# 78   Versicolor
# 76   Versicolor

# %% [markdown]
# # 🔍 Dataset Understanding
#
# ## Overview
#
# Before building a Machine Learning model, it is important to understand the dataset. In this section, we inspect the structure, size, data types, missing values, duplicate records, and statistical summary of the Iris dataset.
#
# This helps us identify any data quality issues and understand the characteristics of the dataset before moving to Exploratory Data Analysis (EDA).

# %%
# ==========================================================
# Dataset Shape
# ==========================================================

print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (150, 5)

# %% [markdown]
# ### Observation
#
# The dataset contains **150 rows** and **5 columns**.
#
# - 150 represents the total number of flower samples.
# - 4 columns are input features.
# - 1 column is the target variable (Species).

# %%
# Display all column names

print(df.columns.tolist())
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'species']

# %% [markdown]
# ### Observation
#
# The dataset consists of four numerical feature columns:
#
# - Sepal Length
# - Sepal Width
# - Petal Length
# - Petal Width
#
# The fifth column represents the flower species (target variable).

# %%
# Dataset Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Observation
#
# The dataset contains:
#
# - 150 records
# - 4 numerical columns (float64)
# - 1 categorical column (Species)
#
# No missing values are present.

# %%
# Data Types

df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species               object
# dtype: object

# %% [markdown]
# ### Observation
#
# All feature columns are numerical (float64), making them suitable for Machine Learning algorithms.
#
# The Species column is an object (categorical) type after mapping the numeric labels to species names.

# %%
# Missing Values

df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %% [markdown]
# ### Observation
#
# There are **no missing values** in the dataset.
#
# This means no data cleaning or imputation is required before training the models.

# %%
# Duplicate Values

print("Duplicate Records:", df.duplicated().sum())
# Out:
# Duplicate Records: 1

# %% [markdown]
# ### Observation
#
# The dataset contains a few duplicate records, which is common in the Iris dataset. Since the dataset is small and duplicates do not represent data entry errors, they can be retained for this educational classification task.

# %%
# Statistical Summary

df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### Observation
#
# The statistical summary provides key insights into the numerical features, including:
#
# - Mean
# - Standard Deviation
# - Minimum Value
# - Maximum Value
# - Quartiles (25%, 50%, 75%)
#
# These statistics help us understand the distribution and range of each feature.

# %%
# Species Distribution

df["species"].value_counts()
# Out:
# species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
# Percentage Distribution

round(df["species"].value_counts(normalize=True) * 100, 2)
# Out:
# species
# Setosa        33.33
# Versicolor    33.33
# Virginica     33.33
# Name: proportion, dtype: float64

# %% [markdown]
# ### Observation
#
# The dataset is perfectly balanced.
#
# Each flower species contains **50 samples (33.33%)**, which helps prevent bias during model training.

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
#
# ## Overview
#
# Exploratory Data Analysis (EDA) is an essential step in any Data Science project. It helps us understand the structure of the dataset, identify patterns, detect outliers, and analyze relationships between features.
#
# In this section, we will visualize the Iris dataset using different plots to better understand the distribution of flower measurements and how they vary across different species.
#
# ### Visualizations Performed
#
# - Species Distribution
# - Pair Plot
# - Box Plots
# - Histograms
# - Correlation Heatmap

# %%
# ==========================================================
# Species Distribution
# ==========================================================

plt.figure(figsize=(7,5))

sns.countplot(
    data=df,
    x="species",
    palette="viridis"
)

plt.title("Distribution of Iris Species", fontsize=15)
plt.xlabel("Species")
plt.ylabel("Count")

plt.tight_layout()

# Save Image
plt.savefig("../images/species_distribution.png", dpi=300)

plt.show()

# %% [markdown]
# ### 📌 Observation
#
# - Each species contains **50 samples**.
# - The dataset is perfectly balanced.
# - A balanced dataset helps Machine Learning models learn equally from all classes and reduces prediction bias.

# %%
# ==========================================================
# Pair Plot
# ==========================================================

pair = sns.pairplot(
    df,
    hue="species",
    palette="viridis",
    diag_kind="hist"
)

pair.fig.suptitle("Pair Plot of Iris Features", y=1.02)

pair.savefig("../images/pairplot.png", dpi=300)

plt.show()

# %% [markdown]
# ### 📌 Observation
#
# - Petal Length and Petal Width clearly separate the three species.
# - Setosa is completely separated from the other two species.
# - Versicolor and Virginica show slight overlap.
# - Petal measurements appear to be the most discriminative features.

# %%
# ==========================================================
# Box Plots
# ==========================================================

features = df.columns[:-1]

plt.figure(figsize=(14,8))

for i, feature in enumerate(features, 1):

    plt.subplot(2,2,i)

    sns.boxplot(
        data=df,
        x="species",
        y=feature,
        palette="viridis"
    )

    plt.title(feature)

plt.tight_layout()

plt.savefig("../images/boxplots.png", dpi=300)

plt.show()

# %% [markdown]
# ### 📌 Observation
#
# - Petal features provide better separation between species.
# - Sepal features show more overlap.
# - A few mild outliers are visible, but they do not significantly affect the dataset.

# %%
# ==========================================================
# Feature Distribution
# ==========================================================

df.hist(
    figsize=(12,8),
    bins=20,
    color="skyblue",
    edgecolor="black"
)

plt.suptitle("Feature Distributions", fontsize=16)

plt.tight_layout()

plt.savefig("../images/histograms.png", dpi=300)

plt.show()

# %% [markdown]
# ### 📌 Observation
#
# - Most numerical features show approximately normal distributions.
# - Petal Width has a wider spread due to differences among species.

# %%
# ==========================================================
# Correlation Heatmap
# ==========================================================

plt.figure(figsize=(8,6))

sns.heatmap(
    df.drop("species", axis=1).corr(),
    annot=True,
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Feature Correlation Heatmap")

plt.tight_layout()

plt.savefig("../images/correlation_heatmap.png", dpi=300)

plt.show()

# %% [markdown]
# ### 📌 Observation
#
# - Petal Length and Petal Width have a strong positive correlation.
# - Sepal Width has a weaker correlation with the other features.
# - Strongly correlated features often provide valuable information for classification models.

# %%
# Species-wise Statistics

df.groupby("species").mean()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# Setosa                  5.006             3.428              1.462
# Versicolor              5.936             2.770              4.260
# Virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# Setosa                 0.246
# Versicolor             1.326
# Virginica              2.026

# %% [markdown]
# ### 📌 Observation
#
# The average measurements differ noticeably among the three species, particularly for petal dimensions. This supports the expectation that petal features are highly useful for classification.

# %% [markdown]
# # 🎯 Feature Selection & Data Preprocessing
#
# ## Overview
#
# Feature selection is the process of identifying the most relevant input variables for building a Machine Learning model.
#
# The Iris dataset contains four numerical features that describe the physical characteristics of flowers. Based on the Exploratory Data Analysis (EDA), **Petal Length** and **Petal Width** are the most discriminative features because they clearly separate the three Iris species.
#
# However, in this project, we will use **all four features** to maximize the information available to the model and improve prediction performance.
#
# ## Selected Features
#
# - Sepal Length (cm)
# - Sepal Width (cm)
# - Petal Length (cm)
# - Petal Width (cm)
#
# ## Target Variable
#
# - Species

# %%
# ==========================================================
# Select Features and Target Variable
# ==========================================================

# Input Features
X = df.drop("species", axis=1)

# Target Variable
y = df["species"]

print("Features Shape :", X.shape)
print("Target Shape   :", y.shape)
# Out:
# Features Shape : (150, 4)
# Target Shape   : (150,)

# %%
# Display Feature Variables

X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### 📌 Observation
#
# The feature matrix consists of four numerical variables representing the flower measurements. These features will be used as inputs for training the Machine Learning models.

# %%
# Display Target Variable

y.head()
# Out:
# 0    Setosa
# 1    Setosa
# 2    Setosa
# 3    Setosa
# 4    Setosa
# Name: species, dtype: object

# %% [markdown]
# ### 📌 Observation
#
# The target variable represents the species of each Iris flower. There are three classes:
#
# - Setosa
# - Versicolor
# - Virginica

# %%
# Class Distribution

y.value_counts()
# Out:
# species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### 📌 Observation
#
# Each species contains **50 samples**, indicating that the dataset is perfectly balanced. Balanced datasets help Machine Learning models learn equally from each class and reduce prediction bias.

# %%
# Feature Summary

X.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### 📌 Observation
#
# The summary statistics show that the four numerical features have different ranges and distributions. These measurements provide the information required for distinguishing between the three Iris species.

# %%
# Correlation Matrix

X.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %% [markdown]
# ### 📌 Observation
#
# Petal Length and Petal Width exhibit a strong positive correlation, indicating that they tend to increase together. These features are particularly informative for classifying Iris flower species.

# %% [markdown]
# # 📌 Feature Scaling
#
# Feature scaling is a preprocessing technique used to bring numerical features onto a similar scale.
#
# In this project, feature scaling is **not applied** because:
#
# - The Iris dataset contains features with relatively similar ranges.
# - Tree-based algorithms such as Decision Tree and Random Forest do not require feature scaling.
# - The objective of this internship task is to compare multiple classification algorithms using the original dataset.
#
# For larger or more complex datasets, feature scaling (e.g., StandardScaler or MinMaxScaler) is often recommended, especially for distance-based algorithms like K-Nearest Neighbors (KNN).

# %% [markdown]
# # ✂️ Train-Test Split
#
# ## Overview
#
# Before training a Machine Learning model, the dataset is divided into two parts:
#
# - **Training Set (80%)** – Used to train the model.
# - **Testing Set (20%)** – Used to evaluate the model.
#
# This ensures that the model is tested on unseen data, providing a fair estimate of its real-world performance.
#
# ### Why use `random_state = 42`?
#
# Setting a fixed random state ensures that the train-test split remains the same every time the notebook is executed, making the results reproducible.

# %%
# ==========================================================
# Train-Test Split
# ==========================================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("✅ Dataset split completed successfully.")
# Out:
# ✅ Dataset split completed successfully.

# %%
print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)

print()

print("Training Target   :", y_train.shape)
print("Testing Target    :", y_test.shape)
# Out:
# Training Features : (120, 4)
# Testing Features  : (30, 4)
#
# Training Target   : (120,)
# Testing Target    : (30,)

# %%
X_train.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 8                  4.4               2.9                1.4               0.2
# 106                4.9               2.5                4.5               1.7
# 76                 6.8               2.8                4.8               1.4
# 9                  4.9               3.1                1.5               0.1
# 89                 5.5               2.5                4.0               1.3

# %%
X_test.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 38                 4.4               3.0                1.3               0.2
# 127                6.1               3.0                4.9               1.8
# 57                 4.9               2.4                3.3               1.0
# 93                 5.0               2.3                3.3               1.0
# 42                 4.4               3.2                1.3               0.2

# %%
y_train.head()
# Out:
# 8          Setosa
# 106     Virginica
# 76     Versicolor
# 9          Setosa
# 89     Versicolor
# Name: species, dtype: object

# %%
y_test.head()
# Out:
# 38         Setosa
# 127     Virginica
# 57     Versicolor
# 93     Versicolor
# 42         Setosa
# Name: species, dtype: object

# %%
print("Training Set Distribution")

print(y_train.value_counts())

print()

print("Testing Set Distribution")

print(y_test.value_counts())
# Out:
# Training Set Distribution
# species
# Setosa        40
# Virginica     40
# Versicolor    40
# Name: count, dtype: int64
#
# Testing Set Distribution
# species
# Setosa        10
# Virginica     10
# Versicolor    10
# Name: count, dtype: int64

# %% [markdown]
# ### 📌 Observation
#
# The dataset has been successfully divided into training and testing sets using an 80:20 ratio.
#
# The `stratify` parameter ensures that the proportion of each Iris species remains the same in both datasets. This prevents class imbalance and leads to a more reliable evaluation of the Machine Learning models.

# %% [markdown]
# # 🤖 Machine Learning Model Building
#
# ## Overview
#
# Machine Learning models learn patterns from historical data and use those patterns to make predictions on unseen data.
#
# In this project, we compare four classification algorithms:
#
# 1. Logistic Regression
# 2. K-Nearest Neighbors (KNN)
# 3. Decision Tree
# 4. Random Forest
#
# Each model will be evaluated using:
#
# - Accuracy Score
# - Confusion Matrix
# - Classification Report
#
# Finally, the best-performing model will be selected based on its performance.

# %% [markdown]
# # 🔹 Model 1 : Logistic Regression
#
# ## Overview
#
# Logistic Regression is a supervised Machine Learning algorithm used for classification problems.
#
# It predicts the probability that a sample belongs to a particular class. Although its name contains "Regression", it is widely used for classification tasks.

# %%
# ==========================================================
# Logistic Regression
# ==========================================================

lr = LogisticRegression(max_iter=200)

lr.fit(X_train, y_train)

lr_pred = lr.predict(X_test)

print("✅ Logistic Regression Model Trained Successfully")
# Out:
# ✅ Logistic Regression Model Trained Successfully

# %%
lr_accuracy = accuracy_score(y_test, lr_pred)

print(f"Accuracy : {lr_accuracy:.4f}")
# Out:
# Accuracy : 0.9667

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    confusion_matrix(y_test, lr_pred),
    annot=True,
    cmap="Blues",
    fmt="d"
)

plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.savefig("../images/confusion_matrix_lr.png", dpi=300)

plt.show()

# %%
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        10
#   Versicolor       1.00      0.90      0.95        10
#    Virginica       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ### 📌 Observation
#
# Logistic Regression achieved a high classification accuracy on the Iris dataset.
#
# Most flower species were classified correctly with only a few minor misclassifications.

# %% [markdown]
# # 🔹 Model 2 : K-Nearest Neighbors (KNN)
#
# ## Overview
#
# K-Nearest Neighbors (KNN) is a distance-based Machine Learning algorithm.
#
# It classifies a new sample by identifying the nearest training samples and assigning the majority class among them.

# %%
# ==========================================================
# KNN
# ==========================================================

knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train, y_train)

knn_pred = knn.predict(X_test)

print("✅ KNN Model Trained Successfully")
# Out:
# ✅ KNN Model Trained Successfully

# %%
knn_accuracy = accuracy_score(y_test, knn_pred)

print(f"Accuracy : {knn_accuracy:.4f}")
# Out:
# Accuracy : 1.0000

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    confusion_matrix(y_test, knn_pred),
    annot=True,
    cmap="Greens",
    fmt="d"
)

plt.title("KNN Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.savefig("../images/confusion_matrix_knn.png", dpi=300)

plt.show()

# %%
print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        10
#   Versicolor       1.00      1.00      1.00        10
#    Virginica       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### 📌 Observation
#
# KNN performs exceptionally well because the Iris dataset contains well-separated classes, especially for the Setosa species.

# %% [markdown]
# # 🔹 Model 3 : Decision Tree
#
# ## Overview
#
# Decision Tree is a supervised learning algorithm that makes decisions using a tree-like structure of rules.
#
# It is easy to interpret and works well for both classification and regression tasks.

# %%
dt = DecisionTreeClassifier(random_state=42)

dt.fit(X_train, y_train)

dt_pred = dt.predict(X_test)

print("✅ Decision Tree Model Trained Successfully")
# Out:
# ✅ Decision Tree Model Trained Successfully

# %%
dt_accuracy = accuracy_score(y_test, dt_pred)

print(f"Accuracy : {dt_accuracy:.4f}")
# Out:
# Accuracy : 0.9333

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    confusion_matrix(y_test, dt_pred),
    annot=True,
    cmap="Oranges",
    fmt="d"
)

plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.savefig("../images/confusion_matrix_dt.png", dpi=300)

plt.show()

# %%
print(classification_report(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        10
#   Versicolor       0.90      0.90      0.90        10
#    Virginica       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# ### 📌 Observation
#
# Decision Tree performs well on the Iris dataset by learning simple decision rules based on flower measurements.

# %% [markdown]
# # 🔹 Model 4 : Random Forest
#
# ## Overview
#
# Random Forest is an ensemble learning algorithm that combines multiple Decision Trees to improve prediction accuracy and reduce overfitting.
#
# It is one of the most widely used classification algorithms in Machine Learning.

# %%
rf = RandomForestClassifier(
    random_state=42
)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

print("✅ Random Forest Model Trained Successfully")
# Out:
# ✅ Random Forest Model Trained Successfully

# %%
rf_accuracy = accuracy_score(y_test, rf_pred)

print(f"Accuracy : {rf_accuracy:.4f}")
# Out:
# Accuracy : 0.9000

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    confusion_matrix(y_test, rf_pred),
    annot=True,
    cmap="Purples",
    fmt="d"
)

plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.savefig("../images/confusion_matrix_rf.png", dpi=300)

plt.show()

# %%
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        10
#   Versicolor       0.82      0.90      0.86        10
#    Virginica       0.89      0.80      0.84        10
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# ### 📌 Observation
#
# Random Forest generally provides excellent performance because it combines multiple decision trees, making the model more robust and reducing overfitting.

# %% [markdown]
# # 📊 Model Comparison
#
# ## Overview
#
# After training multiple Machine Learning models, it is important to compare their performance.
#
# The comparison is based on the **Accuracy Score**, which measures the percentage of correctly classified samples.
#
# The model with the highest accuracy and consistent performance will be selected as the best model for this project.

# %%
# ==========================================================
# Model Comparison
# ==========================================================

comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "K-Nearest Neighbors",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        lr_accuracy,
        knn_accuracy,
        dt_accuracy,
        rf_accuracy
    ]
})

comparison = comparison.sort_values(
    by="Accuracy",
    ascending=False
).reset_index(drop=True)

comparison
# Out:
#                  Model  Accuracy
# 0  K-Nearest Neighbors  1.000000
# 1  Logistic Regression  0.966667
# 2        Decision Tree  0.933333
# 3        Random Forest  0.900000

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=comparison,
    x="Accuracy",
    y="Model",
    palette="viridis"
)

plt.title("Model Accuracy Comparison")

plt.xlim(0.90,1.01)

plt.savefig("../images/model_comparison.png", dpi=300)

plt.show()

# %% [markdown]
# ### 📌 Observation
#
# All four Machine Learning models performed exceptionally well on the Iris dataset.
#
# Among them, the model with the highest accuracy is selected as the final model for prediction.

# %% [markdown]
# # 🏆 Best Model Selection
#
# The best-performing model is selected based on:
#
# - Highest Accuracy
# - Better Generalization
# - Consistent Classification Performance

# %%
best_model = comparison.iloc[0]

print("🏆 Best Model")
print("-"*40)

print("Model    :", best_model["Model"])
print("Accuracy :", round(best_model["Accuracy"]*100,2),"%")
# Out:
# 🏆 Best Model
# ----------------------------------------
# Model    : K-Nearest Neighbors
# Accuracy : 100.0 %

# %% [markdown]
# ### 📌 Observation
#
# The selected model achieved the highest classification accuracy on the test dataset.
#
# It correctly classified almost all flower species, making it the most reliable model for this project.

# %% [markdown]
# # 🌸 Feature Importance
#
# Random Forest provides feature importance scores that indicate which flower measurements contribute the most to species classification.

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#              Feature  Importance
# 3   petal width (cm)    0.437185
# 2  petal length (cm)    0.431466
# 0  sepal length (cm)    0.116349
# 1   sepal width (cm)    0.015000

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=importance,
    x="Importance",
    y="Feature",
    palette="mako"
)

plt.title("Feature Importance")

plt.savefig("../images/feature_importance.png", dpi=300)

plt.show()

# %% [markdown]
# ### 📌 Observation
#
# Petal Length and Petal Width are the most influential features for predicting Iris species.
#
# This confirms the findings from the Exploratory Data Analysis (EDA).

# %% [markdown]
# # 🔮 Sample Prediction
#
# A new flower sample is provided to the trained model to predict its species.

# %%
sample = [[5.1, 3.5, 1.4, 0.2]]

prediction = rf.predict(sample)

print("Sample Flower")

print("Sepal Length :", sample[0][0])
print("Sepal Width  :", sample[0][1])
print("Petal Length :", sample[0][2])
print("Petal Width  :", sample[0][3])

print()

print("🌸 Predicted Species :", prediction[0])
# Out:
# Sample Flower
# Sepal Length : 5.1
# Sepal Width  : 3.5
# Petal Length : 1.4
# Petal Width  : 0.2
#
# 🌸 Predicted Species : Setosa

# %% [markdown]
# # 📝 Conclusion
#
# ## Project Summary
#
# In this project, we successfully developed a Machine Learning classification model to predict the species of Iris flowers using four physical measurements.
#
# The project included:
#
# - Loading the Iris dataset
# - Data exploration and visualization
# - Feature analysis
# - Data preprocessing
# - Training multiple Machine Learning models
# - Model evaluation using Accuracy, Confusion Matrix, and Classification Report
# - Model comparison
# - Sample prediction
#
# ## Key Findings
#
# - The dataset is clean and balanced.
# - Petal Length and Petal Width are the most informative features.
# - All four Machine Learning models achieved excellent performance.
# - The selected best model demonstrated outstanding classification accuracy on unseen test data.
#
# ## Learning Outcomes
#
# Through this project, I gained practical experience in:
#
# - Exploratory Data Analysis (EDA)
# - Data Visualization
# - Supervised Machine Learning
# - Model Evaluation
# - Classification Algorithms using Scikit-learn

# %%
print("="*60)
print("🌸 Iris Flower Classification Project Completed Successfully!")
print("="*60)

print("\nProject Steps Completed:")

steps = [
    "Project Overview",
    "Import Libraries",
    "Load Dataset",
    "Dataset Understanding",
    "Exploratory Data Analysis",
    "Feature Selection",
    "Train-Test Split",
    "Logistic Regression",
    "KNN",
    "Decision Tree",
    "Random Forest",
    "Model Comparison",
    "Feature Importance",
    "Sample Prediction",
    "Conclusion"
]

for i, step in enumerate(steps, start=1):
    print(f"{i}. {step}")

print("\n🎯 Internship Task 1 Completed Successfully!")
# Out:
# ...
# 🌸 Iris Flower Classification Project Completed Successfully!
# ...
#
# Project Steps Completed:
# 1. Project Overview
# 2. Import Libraries
# 3. Load Dataset
# 4. Dataset Understanding
# 5. Exploratory Data Analysis
# 6. Feature Selection
# 7. Train-Test Split
# 8. Logistic Regression
# 9. KNN
# 10. Decision Tree
# 11. Random Forest
# 12. Model Comparison
# 13. Feature Importance
# 14. Sample Prediction
# 15. Conclusion
#
# 🎯 Internship Task 1 Completed Successfully!
